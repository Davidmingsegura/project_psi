# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/davidsegura/git/project_Ib_PSI/Raw_values_average_exp.csv')

# %%
df
# Out:
#                    Time  CO_2 [%]    CO [%]  NO_x [%]  O_2 [%]  H_2O [%]  \
# 0      25.06.2024 12:32  0.048985  0.002565  0.000009      NaN  0.049187
# 1      25.06.2024 12:32  0.049035  0.002569  0.000004      NaN  0.049239
# 2      25.06.2024 12:32  0.049035  0.002569  0.000004      NaN  0.049239
# 3      25.06.2024 12:32  0.049141  0.002569 -0.000004  20.6011  0.049340
# 4      25.06.2024 12:32  0.049214  0.002569 -0.000004  20.6010  0.049409
# ...                 ...       ...       ...       ...      ...       ...
# 12138  25.06.2024 15:54       NaN  0.205019 -0.000714  17.9806       NaN
# 12139  25.06.2024 15:54       NaN  0.204676 -0.000699  17.9766       NaN
# 12140  25.06.2024 15:54       NaN  0.204676 -0.000699  17.9724       NaN
# 12141  25.06.2024 15:54       NaN  0.204514 -0.000690  17.9724       NaN
# 12142  25.06.2024 15:54       NaN  0.204194 -0.000690  17.9648       NaN
#
#          N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)
# ...

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#                    Time  CO_2 [%]    CO [%]  NO_x [%]  O_2 [%]  H_2O [%]  \
# 0      25.06.2024 12:32  0.048985  0.002565  0.000009   0.0000  0.049187
# 1      25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 2      25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 3      25.06.2024 12:32  0.049141  0.002569 -0.000004  20.6011  0.049340
# 4      25.06.2024 12:32  0.049214  0.002569 -0.000004  20.6010  0.049409
# ...                 ...       ...       ...       ...      ...       ...
# 12138  25.06.2024 15:54  0.000000  0.205019 -0.000714  17.9806  0.000000
# 12139  25.06.2024 15:54  0.000000  0.204676 -0.000699  17.9766  0.000000
# 12140  25.06.2024 15:54  0.000000  0.204676 -0.000699  17.9724  0.000000
# 12141  25.06.2024 15:54  0.000000  0.204514 -0.000690  17.9724  0.000000
# 12142  25.06.2024 15:54  0.000000  0.204194 -0.000690  17.9648  0.000000
#
#          N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)
# ...

# %%
df['Temperature (°C)'] = df['Temperature (°C)'].astype(float)

# %%
df.head()
# Out:
#                Time  CO_2 [%]    CO [%]  NO_x [%]  O_2 [%]  H_2O [%]  \
# 0  25.06.2024 12:32  0.048985  0.002565  0.000009   0.0000  0.049187
# 1  25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 2  25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 3  25.06.2024 12:32  0.049141  0.002569 -0.000004  20.6011  0.049340
# 4  25.06.2024 12:32  0.049214  0.002569 -0.000004  20.6010  0.049409
#
#      N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)
# 0   0.000000             0.006696           22.6815
# 1   0.000000             0.006700           22.6839
# 2   0.000000             0.006700           22.6839
# 3  79.297854             0.006711           22.6793
# 4  79.297812             0.006711           22.6793

# %%
df['rounded_temperature'] = df['Temperature (°C)'].round()

# %%
df
# Out:
#                    Time  CO_2 [%]    CO [%]  NO_x [%]  O_2 [%]  H_2O [%]  \
# 0      25.06.2024 12:32  0.048985  0.002565  0.000009   0.0000  0.049187
# 1      25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 2      25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 3      25.06.2024 12:32  0.049141  0.002569 -0.000004  20.6011  0.049340
# 4      25.06.2024 12:32  0.049214  0.002569 -0.000004  20.6010  0.049409
# ...                 ...       ...       ...       ...      ...       ...
# 12138  25.06.2024 15:54  0.000000  0.205019 -0.000714  17.9806  0.000000
# 12139  25.06.2024 15:54  0.000000  0.204676 -0.000699  17.9766  0.000000
# 12140  25.06.2024 15:54  0.000000  0.204676 -0.000699  17.9724  0.000000
# 12141  25.06.2024 15:54  0.000000  0.204514 -0.000690  17.9724  0.000000
# 12142  25.06.2024 15:54  0.000000  0.204194 -0.000690  17.9648  0.000000
#
#          N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)  rounded_temperature
# ...

# %%
grouped_df = df.groupby('rounded_temperature').mean(numeric_only=True).reset_index()

# %%
grouped_df
# Out:
#      rounded_temperature  CO_2 [%]    CO [%]  NO_x [%]    O_2 [%]  H_2O [%]  \
# 0                   23.0  0.050179  0.002600  0.000007  20.369964  0.050359
# 1                   24.0  0.050894  0.002580 -0.000004  20.594850  0.051023
# 2                   25.0  0.051480  0.002620  0.000006  20.594333  0.051619
# 3                   26.0  0.052349  0.002652  0.000007  20.594350  0.052479
# 4                   27.0  0.053318  0.002670  0.000009  20.593200  0.053421
# ..                   ...       ...       ...       ...        ...       ...
# 357                380.0  6.117034  0.055306  0.004298  14.247971  5.564429
# 358                381.0  6.231168  0.055757  0.004448  14.144476  5.661901
# 359                382.0  6.235759  0.057718  0.004433  14.104022  5.667471
# 360                383.0  6.302957  0.057911  0.004486  14.059200  5.724712
# 361                384.0  6.302110  0.058165  0.004496  14.057200  5.724209
#
#        N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)
# ...

# %%
grouped_df.to_csv('/Users/davidsegura/git/project_Ib_PSI/averaged_values.csv', index=False)

# %%
df_2 = pd.read_csv('/Users/davidsegura/git/project_Ib_PSI/Raw_values_average_exp.csv')
df_2.fillna(0, inplace=True)
df_2['Temperature (°C)'] = df_2['Temperature (°C)'].astype(float)
df_2['rounded_temperature'] = df_2['Temperature (°C)'].round()
df_2
# Out:
#                    Time  CO_2 [%]    CO [%]  NO_x [%]  O_2 [%]  H_2O [%]  \
# 0      25.06.2024 12:32  0.048985  0.002565  0.000009   0.0000  0.049187
# 1      25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 2      25.06.2024 12:32  0.049035  0.002569  0.000004   0.0000  0.049239
# 3      25.06.2024 12:32  0.049141  0.002569 -0.000004  20.6011  0.049340
# 4      25.06.2024 12:32  0.049214  0.002569 -0.000004  20.6010  0.049409
# ...                 ...       ...       ...       ...      ...       ...
# 12138  25.06.2024 15:54  0.000000  0.205019 -0.000714  17.9806  0.000000
# 12139  25.06.2024 15:54  0.000000  0.204676 -0.000699  17.9766  0.000000
# 12140  25.06.2024 15:54  0.000000  0.204676 -0.000699  17.9724  0.000000
# 12141  25.06.2024 15:54  0.000000  0.204514 -0.000690  17.9724  0.000000
# 12142  25.06.2024 15:54  0.000000  0.204194 -0.000690  17.9648  0.000000
#
#          N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)  rounded_temperature
# ...

# %%
df_25 = df_2[df_2['rounded_temperature'] == 25]

# %%
df_25
# Out:
#                  Time  CO_2 [%]    CO [%]  NO_x [%]  O_2 [%]  H_2O [%]  \
# 271  25.06.2024 12:36  0.051264  0.002609  0.000005  20.5943  0.051403
# 272  25.06.2024 12:36  0.051469  0.002620  0.000004  20.5943  0.051608
# 273  25.06.2024 12:36  0.051708  0.002630  0.000008  20.5944  0.051846
#
#        N_2 [%]  m_{Rauchgas} [kg/s]  Temperature (°C)  rounded_temperature
# 271  79.300420             0.008276           24.6532                 25.0
# 272  79.299999             0.008258           25.0360                 25.0
# 273  79.299408             0.008275           25.3627                 25.0

# %%
lists_temp = [25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350]

# %%
for i in lists_temp:
    df_i = df_2[df_2['rounded_temperature'] == i]
    sorted_df = df_i.sort_values(by='Time')
     
    output_file_path = f'/Users/davidsegura/git/project_Ib_PSI/filtered_{int(i)}_degrees.csv'
    sorted_df.to_csv(output_file_path, index=False)
